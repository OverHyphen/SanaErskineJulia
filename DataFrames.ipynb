# %%
using Plots

# %%
using DataFrames

# %%
df = DataFrame(
    Names=["Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica"],
    PetalWidth= [0.3, 0.3, 0.2, 0.6, 0.4, 0.3, 0.2, 0.2, 0.2, 0.2, 1.2, 1.4, 1.2, 1, 1.3, 1.2, 1.3, 1.3, 1.1, 1.3, 2.4, 2.3, 1.9, 2.3, 2.5, 2.3, 1.9, 2, 2.3, 1.8],
    PetalLength= [1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.4, 4.6, 4, 3.3, 4.2, 4.2, 4.2, 4.3, 3, 4.1, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5, 5.2, 5.4, 5.1], 
    SepalWidth= [3.5, 2.3, 3.2, 3.5, 3.8, 3, 3.8, 3.2, 3.7, 3.3, 2.6, 3, 2.6, 2.3, 2.7, 3, 2.9, 2.9, 2.5, 2.8, 3.1, 3.1, 2.7, 3.2, 3.3, 3, 2.5, 3, 3.4, 3],
    SepalLength= [5, 4.5, 4.4, 5, 5.1, 4.8, 5.1, 4.6, 5.3, 5, 5.5, 6.1, 5.8, 5, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]
)
# Out:
# 30×5 DataFrame
#  Row │ Names            PetalWidth  PetalLength  SepalWidth  SepalLength
#      │ String           Float64     Float64      Float64     Float64
# ─────┼───────────────────────────────────────────────────────────────────
#    1 │ Iris-setosa             0.3          1.3         3.5          5.0
#    2 │ Iris-setosa             0.3          1.3         2.3          4.5
#    3 │ Iris-setosa             0.2          1.3         3.2          4.4
#    4 │ Iris-setosa             0.6          1.6         3.5          5.0
#    5 │ Iris-setosa             0.4          1.9         3.8          5.1
#    6 │ Iris-setosa             0.3          1.4         3.0          4.8
#    7 │ Iris-setosa             0.2          1.6         3.8          5.1
#    8 │ Iris-setosa             0.2          1.4         3.2          4.6
#    9 │ Iris-setosa             0.2          1.5         3.7          5.3
#   10 │ Iris-setosa             0.2          1.4         3.3          5.0
# ...

# %%
a = 8
plot(a)

# %%
using Statistics

# %%
SePetalWidth = [0.3, 0.3, 0.2, 0.6, 0.4]
VePetalWidth = [1.2, 1.4, 1.2, 1, 1.3]
ViPetalWidth = [2.4, 2.3, 1.9, 2.3, 2.5]
SePetalLength = [1.3, 1.3, 1.3, 1.6, 1.9]
VePetalLength = [4.4, 4.6, 4, 3.3, 4.2]
ViPetalLength = [5.6, 5.1, 5.1, 5.9, 5.7]
# Out:
# 5-element Vector{Float64}:
#  5.6
#  5.1
#  5.1
#  5.9
#  5.7

# %%
A = mean(SePetalWidth)
# Out:
# 0.36

# %%
B = mean(VePetalWidth)
# Out:
# 1.22

# %%
C = mean(ViPetalWidth)
# Out:
# 2.28

# %%
D = mean(SePetalLength)
# Out:
# 1.48

# %%
E = mean(VePetalLength)
# Out:
# 4.1

# %%
F = mean(ViPetalLength)
# Out:
# 5.4799999999999995

# %%
x = [1, 22, 10]
y = [A, B, C]

bar(x, y, title = "Average Petal Width per Species", ylabel = "Petal Width")

# %%
x = [1, 22, 10]
y = [D, E, F]

bar(x, y, title = "Average Petal Length per Species", ylabel = "Petal Length")
